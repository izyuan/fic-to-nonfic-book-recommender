# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df = pd.read_csv('data\cleaned_output_file.csv')
df
# Out:
#                                            Book Title  \
# 0     the diary of a young girl mass market paperback
# 1      sapiens a brief history of humankind paperback
# 2                                  educated hardcover
# 3   quiet the power of introverts in a world that ...
# 4      the immortal life of henrietta lacks hardcover
# 5   freakonomics a rogue economist explores the hi...
# 6             outliers the story of success hardcover
# 7                                  becoming hardcover
# 8   the devil in the white city murder magic and m...
# 9   atomic habits an easy proven way to build good...
# 10     a short history of nearly everything paperback
# 11          we should all be feminists kindle edition
# 12  the subtle art of not giving a f ck a counteri...
# 13                         i'm glad my mom died ebook
# 14                          night the night trilogy 1
# 15                       into the wild kindle edition
# ...

# %%
avg_ratings = df['Average Rating']
publish_date = df['Publish Date']
avg_ratings= avg_ratings.sort_values(ascending=False)
publish_date = publish_date.sort_values(ascending=True)
publish_date
# Out:
# 41    -400
# 40    1936
# 0     1947
# 14    1956
# 22    1959
# 17    1959
# 39    1985
# 27    1988
# 15    1996
# 18    1997
# 37    1998
# 21    2000
# 30    2000
# 26    2003
# 10    2003
# 8     2003
# 29    2005
# 23    2005
# 5     2005
# 44    2006
# 6     2008
# 4     2010
# 28    2010
# 32    2010
# 1     2011
# 25    2011
# 19    2011
# 11    2012
# 3     2012
# 33    2012
# 34    2012
# 38    2014
# 43    2014
# 20    2015
# 42    2015
# 24    2016
# 12    2016
# 46    2016
# 16    2016
# 31    2017
# 45    2017
# 47    2018
# 36    2018
# 7     2018
# 9     2018
# 2     2018
# 35    2019
# 13    2022
# Name: Publish Date, dtype: int64
